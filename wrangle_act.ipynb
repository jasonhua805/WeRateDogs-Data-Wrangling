# %% [markdown]
# # WeRateDogs Twitter Data Wrangling Project
#
# In today's project, we will be loading in data from the WeRateDogs tweet archive, which was provided to Udacity directly from the WeRateDogs account owners.
#
# WeRateDogs is a popular Twitter account that rates people's dogs with a unique scoring system that frequently goes above 10/10 in addition to providing a humorous comment. It is a very popular account on the social media platform, with over 8.8 million followers as of 10/10/2020.
#
# We will firstly supplement this Udacity data with some additional key data points (# of Likes/Favorites and # of Retweets) using Tweepy - Twitter's Developer API. We are also adding in some datapoints which contain predictions for each of the dog's breeds extracted from a file that was created using a Udacity designed machine learning software.
#
# We will then wrangle this data into a semi-clean presentation before going into a preliminary analysis and visualization of our data.

# %%
import pandas as pd
import numpy as np
import requests
import json
import dill
import datetime
import matplotlib.pyplot as plt
% matplotlib inline
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# # Twitter API Process:
# Note that for the code below to function, it is required to provide various keys and tokens to use the Twitter API. I do not provide the keys I personally used here in accordance with proper practice for private APIs.
#
# If you are observing or evaluating this project for just the wrangling process, please skip to the "To Skip the Twitter API Process" section to load in the dataframe that will be used in the wrangling process

# %%
# The keys and token codes used during the project have been redacted in
# accordance with proper practice when using private APIs

import tweepy

consumer_key = 'cdcfmZ02qe83c7SzmcrF2BhPO'
consumer_secret = '7IlBSbpRJPuRjA0fc4JVS9FZBgM4QjAI97HVSLSxjNyCxLKYnu'
access_token = '254325276-6eGRWxXvReC5iBAzQpIAzd6LkZ2WjzYfZj9tj1Vi'
access_secret = 'F2Rd1H7NSuwVnySQ8BOB9LBUHVTjzrG1YHLBRMu4DdMFm'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

# %%
# Reading in the WeRateDogs Twitter Archive data
df = pd.read_csv('twitter-archive-enhanced.csv')

# %% [markdown]
# The following code is accessing a Udacity hosted file which contains predictions for each of the dog's breed based on an internally created machine learning software.

# %%
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)

# %%
with open('image_predictions.tsv', mode='wb') as file:
    file.write(response.content)

# %%
df2 = pd.read_csv('image_predictions.tsv',sep = '\t')

# %%
# Creating Columns to hold our Tweet Favorite and Retweet Counts
df['favorite_count'] = ""
df['retweet_count'] = ""

# %%
with open('tweet_json.txt') as json_file:
    data = json.load(json_file)

# %%
data = {}
data['tweet_data'] = []

for tweet_id in range(len(df.tweet_id)):
    try:
        tweet = api.get_status(df.tweet_id[tweet_id],wait_on_rate_limit=True,wait_on_rate_limit_notify=True)
        data['tweet_data'].append({
            'tweet_id': int(df.tweet_id[tweet_id]),
            'favorite_count': tweet.favorite_count,
            'retweet_count': tweet.retweet_count
        })
    except:
        continue
# Out:
# Rate limit reached. Sleeping for: 743
# Rate limit reached. Sleeping for: 743

# %%
for tweet in range(len(data['tweet_data'])):
    df['favorite_count'][tweet] = data['tweet_data'][tweet]['favorite_count']
    df['retweet_count'][tweet] = data['tweet_data'][tweet]['retweet_count']
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
with open('tweet_json.txt', 'w') as outfile:
    json.dump(data,outfile)

# %% [markdown]
# This code now merges our tweet dataframe with the image predictions dataframe to give our final dataframe upon which we will now assess and clean some of the underlying issues:

# %%
dogsdf = pd.merge(df,df2,on=['tweet_id'],how='left')

# %% [markdown]
# Now we save this combined data frame (still yet to be wrangled) into a new csv file which we can load in at anytime without having to go through the Tweepy process again.

# %%
dogsdf.to_csv('tweet_df.csv')

# %% [markdown]
# # To Skip the Twitter API Process:
#
# In order to demonstrate the functionality of the code used in the data wrangling process, I will be loading in the dataframe that would have been created if the Twitter API process above was followed. This dataframe below is provided so that the rest of this project can be observed/evaluated without need for developer access to the Twitter API.

# %% [markdown]
# This code now merges our tweet dataframe with the image predictions dataframe to give our final dataframe upon which we will now assess and clean some of the underlying issues:

# %%
dogsdf = pd.read_csv('tweet_df.csv')

# %% [markdown]
# # Wrangling Process

# %%
dogsdf
# Out:
#       Unnamed: 0            tweet_id  in_reply_to_status_id  \
# 0     0           892420643555336193 NaN
# 1     1           892177421306343426 NaN
# 2     2           891815181378084864 NaN
# 3     3           891689557279858688 NaN
# 4     4           891327558926688256 NaN
# 5     5           891087950875897856 NaN
# 6     6           890971913173991426 NaN
# 7     7           890729181411237888 NaN
# 8     8           890609185150312448 NaN
# 9     9           890240255349198849 NaN
# 10    10          890006608113172480 NaN
# 11    11          889880896479866881 NaN
# 12    12          889665388333682689 NaN
# 13    13          889638837579907072 NaN
# 14    14          889531135344209921 NaN
# 15    15          889278841981685760 NaN
# 16    16          888917238123831296 NaN
# 17    17          888804989199671297 NaN
# 18    18          888554962724278272 NaN
# 19    19          888202515573088257 NaN
# 20    20          888078434458587136 NaN
# 21    21          887705289381826560 NaN
# 22    22          887517139158093824 NaN
# 23    23          887473957103951883 NaN
# 24    24          887343217045368832 NaN
# 25    25          887101392804085760 NaN
# 26    26          886983233522544640 NaN
# 27    27          886736880519319552 NaN
# 28    28          886680336477933568 NaN
# 29    29          886366144734445568 NaN
# ...   ..                         ...  ..
# 2326  2326        666411507551481857 NaN
# 2327  2327        666407126856765440 NaN
# 2328  2328        666396247373291520 NaN
# 2329  2329        666373753744588802 NaN
# 2330  2330        666362758909284353 NaN
# 2331  2331        666353288456101888 NaN
# 2332  2332        666345417576210432 NaN
# 2333  2333        666337882303524864 NaN
# 2334  2334        666293911632134144 NaN
# 2335  2335        666287406224695296 NaN
# 2336  2336        666273097616637952 NaN
# 2337  2337        666268910803644416 NaN
# 2338  2338        666104133288665088 NaN
# 2339  2339        666102155909144576 NaN
# 2340  2340        666099513787052032 NaN
# 2341  2341        666094000022159362 NaN
# 2342  2342        666082916733198337 NaN
# 2343  2343        666073100786774016 NaN
# 2344  2344        666071193221509120 NaN
# 2345  2345        666063827256086533 NaN
# 2346  2346        666058600524156928 NaN
# 2347  2347        666057090499244032 NaN
# 2348  2348        666055525042405380 NaN
# 2349  2349        666051853826850816 NaN
# 2350  2350        666050758794694657 NaN
# 2351  2351        666049248165822465 NaN
# 2352  2352        666044226329800704 NaN
# 2353  2353        666033412701032449 NaN
# 2354  2354        666029285002620928 NaN
# 2355  2355        666020888022790149 NaN
#
#       in_reply_to_user_id                  timestamp  \
# 0    NaN                   2017-08-01 16:23:56 +0000
# 1    NaN                   2017-08-01 00:17:27 +0000
# 2     NaN                         ...    1.0     Chihuahua
# 3     NaN                         ...    1.0     paper_towel
# 4     NaN                         ...    2.0     basset
# 5     NaN                         ...    1.0     Chesapeake_Bay_retriever
# 6     NaN                         ...    1.0     Appenzeller
# 7     NaN                         ...    2.0     Pomeranian
# 8     NaN                         ...    1.0     Irish_terrier
# 9     NaN                         ...    1.0     Pembroke
# 10    NaN                         ...    1.0     Samoyed
# 11    NaN                         ...    1.0     French_bulldog
# 12    NaN                         ...    1.0     Pembroke
# 13    NaN                         ...    1.0     French_bulldog
# 14    NaN                         ...    1.0     golden_retriever
# 15    NaN                         ...    1.0     whippet
# 16    NaN                         ...    1.0     golden_retriever
# 17    NaN                         ...    1.0     golden_retriever
# 18    NaN                         ...    3.0     Siberian_husky
# 19    2017-07-19 00:47:34 +0000   ...    2.0     Pembroke
# 20    NaN                         ...    1.0     French_bulldog
# 21    NaN                         ...    1.0     basset
# 22    NaN                         ...    1.0     limousine
# 23    NaN                         ...    2.0     Pembroke
# 24    NaN                         ...    1.0     Mexican_hairless
# 25    NaN                         ...    1.0     Samoyed
# 26    NaN                         ...    2.0     Chihuahua
# 27    NaN                         ...    1.0     kuvasz
# 28    NaN                         ...    1.0     convertible
# 29    NaN                         ...    1.0     French_bulldog
# ...   ...                         ...    ...                ...
# 2326  NaN                         ...    1.0     coho
# 2327  NaN                         ...    1.0     black-and-tan_coonhound
# 2328  NaN                         ...    1.0     Chihuahua
# 2329  NaN                         ...    1.0     soft-coated_wheaten_terrier
# 2330  NaN                         ...    1.0     guinea_pig
# 2331  NaN                         ...    1.0     malamute
# 2332  NaN                         ...    1.0     golden_retriever
# 2333  NaN                         ...    1.0     ox
# 2334  NaN                         ...    1.0     three-toed_sloth
# 2335  NaN                         ...    1.0     Maltese_dog
# 2336  NaN                         ...    1.0     Italian_greyhound
# 2337  NaN                         ...    1.0     desktop_computer
# 2338  NaN                         ...    1.0     hen
# 2339  NaN                         ...    1.0     English_setter
# 2340  NaN                         ...    1.0     Lhasa
# 2341  NaN                         ...    1.0     bloodhound
# 2342  NaN                         ...    1.0     pug
# 2343  NaN                         ...    1.0     Walker_hound
# 2344  NaN                         ...    1.0     Gordon_setter
# 2345  NaN                         ...    1.0     golden_retriever
# 2346  NaN                         ...    1.0     miniature_poodle
# 2347  NaN                         ...    1.0     shopping_cart
# 2348  NaN                         ...    1.0     chow
# 2349  NaN                         ...    1.0     box_turtle
# 2350  NaN                         ...    1.0     Bernese_mountain_dog
# 2351  NaN                         ...    1.0     miniature_pinscher
# 2352  NaN                         ...    1.0     Rhodesian_ridgeback
# 2353  NaN                         ...    1.0     German_shepherd
# 2354  NaN                         ...    1.0     redbone
# 2355  NaN                         ...    1.0     Welsh_springer_spaniel
#
#        p1_conf p1_dog                        p2   p2_conf p2_dog  \
# 0     0.097049  False  bagel                     0.085851  False
# 1     0.323581  True   Pekinese                  0.090647  True
# 2     0.716012  True   malamute                  0.078253  True
# 3     0.170278  False  Labrador_retriever        0.168086  True
# 4     0.555712  True   English_springer          0.225770  True
# 5     0.425595  True   Irish_terrier             0.116317  True
# 6     0.341703  True   Border_collie             0.199287  True
# 7     0.566142  True   Eskimo_dog                0.178406  True
# 8     0.487574  True   Irish_setter              0.193054  True
# 9     0.511319  True   Cardigan                  0.451038  True
# 10    0.957979  True   Pomeranian                0.013884  True
# 11    0.377417  True   Labrador_retriever        0.151317  True
# 12    0.966327  True   Cardigan                  0.027356  True
# 13    0.991650  True   boxer                     0.002129  True
# 14    0.953442  True   Labrador_retriever        0.013834  True
# 15    0.626152  True   borzoi                    0.194742  True
# 16    0.714719  True   Tibetan_mastiff           0.120184  True
# 17    0.469760  True   Labrador_retriever        0.184172  True
# 18    0.700377  True   Eskimo_dog                0.166511  True
# 19    0.809197  True   Rhodesian_ridgeback       0.054950  True
# 20    0.995026  True   pug                       0.000932  True
# 21    0.821664  True   redbone                   0.087582  True
# 22    0.130432  False  tow_truck                 0.029175  False
# 23    0.809197  True   Rhodesian_ridgeback       0.054950  True
# 24    0.330741  True   sea_lion                  0.275645  False
# 25    0.733942  True   Eskimo_dog                0.035029  True
# 26    0.793469  True   toy_terrier               0.143528  True
# 27    0.309706  True   Great_Pyrenees            0.186136  True
# 28    0.738995  False  sports_car                0.139952  False
# 29    0.999201  True   Chihuahua                 0.000361  True
# ...        ...   ...         ...                      ...   ...
# 2326  0.404640  False  barracouta                0.271485  False
# 2327  0.529139  True   bloodhound                0.244220  True
# 2328  0.978108  True   toy_terrier               0.009397  True
# 2329  0.326467  True   Afghan_hound              0.259551  True
# 2330  0.996496  False  skunk                     0.002402  False
# 2331  0.336874  True   Siberian_husky            0.147655  True
# 2332  0.858744  True   Chesapeake_Bay_retriever  0.054787  True
# 2333  0.416669  False  Newfoundland              0.278407  True
# 2334  0.914671  False  otter                     0.015250  False
# 2335  0.857531  True   toy_poodle                0.063064  True
# 2336  0.176053  True   toy_terrier               0.111884  True
# 2337  0.086502  False  desk                      0.085547  False
# 2338  0.965932  False  cock                      0.033919  False
# 2339  0.298617  True   Newfoundland              0.149842  True
# 2340  0.582330  True   Shih-Tzu                  0.166192  True
# 2341  0.195217  True   German_shepherd           0.078260  True
# 2342  0.489814  True   bull_mastiff              0.404722  True
# 2343  0.260857  True   English_foxhound          0.175382  True
# 2344  0.503672  True   Yorkshire_terrier         0.174201  True
# 2345  0.775930  True   Tibetan_mastiff           0.093718  True
# 2346  0.201493  True   komondor                  0.192305  True
# 2347  0.962465  False  shopping_basket           0.014594  False
# 2348  0.692517  True   Tibetan_mastiff           0.058279  True
# 2349  0.933012  False  mud_turtle                0.045885  False
# 2350  0.651137  True   English_springer          0.263788  True
# 2351  0.560311  True   Rottweiler                0.243682  True
# 2352  0.408143  True   redbone                   0.360687  True
# 2353  0.596461  True   malinois                  0.138584  True
# 2354  0.506826  True   miniature_pinscher        0.074192  True
# 2355  0.465074  True   collie                    0.156665  True
#
#                                p3   p3_conf  p3_dog
# 0     banana                       0.076110  False
# 1     papillon                     0.068957  True
# 2     kelpie                       0.031379  True
# 3     spatula                      0.040836  False
# 4     German_short-haired_pointer  0.175219  True
# 5     Indian_elephant              0.076902  False
# 6     ice_lolly                    0.193548  False
# 7     Pembroke                     0.076507  True
# 8     Chesapeake_Bay_retriever     0.118184  True
# 9     Chihuahua                    0.029248  True
# 10    chow                         0.008167  True
# 11    muzzle                       0.082981  False
# 12    basenji                      0.004633  True
# 13    Staffordshire_bullterrier    0.001498  True
# 14    redbone                      0.007958  True
# 15    Saluki                       0.027351  True
# 16    Labrador_retriever           0.105506  True
# 17    English_setter               0.073482  True
# 18    malamute                     0.111411  True
# 19    beagle                       0.038915  True
# 20    bull_mastiff                 0.000903  True
# 21    Weimaraner                   0.026236  True
# 22    shopping_cart                0.026321  False
# 23    beagle                       0.038915  True
# 24    Weimaraner                   0.134203  True
# 25    Staffordshire_bullterrier    0.029705  True
# 26    can_opener                   0.032253  False
# 27    Dandie_Dinmont               0.086346  True
# 28    car_wheel                    0.044173  False
# 29    Boston_bull                  0.000076  True
# ...           ...                       ...   ...
# 2326  gar                          0.189945  False
# 2327  flat-coated_retriever        0.173810  True
# 2328  papillon                     0.004577  True
# 2329  briard                       0.206803  True
# 2330  hamster                      0.000461  False
# 2331  Eskimo_dog                   0.093412  True
# 2332  Labrador_retriever           0.014241  True
# 2333  groenendael                  0.102643  True
# 2334  great_grey_owl               0.013207  False
# 2335  miniature_poodle             0.025581  True
# 2336  basenji                      0.111152  True
# 2337  bookcase                     0.079480  False
# 2338  partridge                    0.000052  False
# 2339  borzoi                       0.133649  True
# 2340  Dandie_Dinmont               0.089688  True
# 2341  malinois                     0.075628  True
# 2342  French_bulldog               0.048960  True
# 2343  Ibizan_hound                 0.097471  True
# 2344  Pekinese                     0.109454  True
# 2345  Labrador_retriever           0.072427  True
# 2346  soft-coated_wheaten_terrier  0.082086  True
# 2347  golden_retriever             0.007959  True
# 2348  fur_coat                     0.054449  False
# 2349  terrapin                     0.017885  False
# 2350  Greater_Swiss_Mountain_dog   0.016199  True
# 2351  Doberman                     0.154629  True
# 2352  miniature_pinscher           0.222752  True
# 2353  bloodhound                   0.116197  True
# 2354  Rhodesian_ridgeback          0.072010  True
# 2355  Shetland_sheepdog            0.061428  True
#
# [2356 rows x 31 columns]

# %% [markdown]
# Quality Issues:
# - Some of the observations/entries are retweets. We need to delete these because we only want original data and don't want to double count anything.
# - Some of the entries are reply tweets from the WeRateDogs account on other Twitter accounts' tweets. We don't want to include these reply tweets in our analysis because they skew the data due to receiving far less exposure than the regular tweets that come directly from WeRateDogs themselves. The breed prediction model also doesn't work on these since the picture is not a direct part of the reply tweet.
# - Some of the remaining entries after cleaning the first two quality issues are not actually dog ratings and are just tweets about unrelated matters like bands or hotdogs or the date.
# - There are a few tweets that seem to have been deleted at some time between its original posting and this project's commencement (October 2020). This means that Tweepy was unable to gather tweet favorite/retweet data since the tweet no longer exists.
# - There are a few tweets in which the image prediction algorithm was unable to produce a result.
# - There are some scores which have a denominator that is not equal to 10. This should not be the case since WeRateDogs is rigorously consistent in using a x/10 rating system.
# - Timestamp values do not need to have the "+0000" at the end. It should be in the "datetime" data type, not a string/object.
# - Retweet and Favorite Count should be integer datatype, not a float.
#
# Tidiness Issues:
# - There are a lot of extra columns, some of which don't provide any data or variables (e.g. Retweet ID and Reply To ID) particularly after deleting the retweeted and reply tweet entries (part of our Quality Issues cleaning process)
# - The stage of the dog's life should be one column instead of four.

# %% [markdown]
# # Creating a copy of our dataframe to work on

# %%
dogsdf_clean = dogsdf.copy()

# %% [markdown]
# ## Quality Issue #1: - Some of the observations/entries are retweets. We need to delete these because we only want original data and don't want to double count anything.

# %% [markdown]
# Define:
#
# We will be identifying all of the entries which have non NaN values in the "retweeted_status_id" column and then deleting them from our dataframe.

# %% [markdown]
# Code:

# %%
for entries in range(len(dogsdf_clean)):
    if(np.isnan(dogsdf_clean['retweeted_status_id'][entries])):
        continue
    else:
        dogsdf_clean.drop([entries],inplace=True)

dogsdf_clean.reset_index(drop = True, inplace=True)

# %% [markdown]
# Check:

# %%
dogsdf_clean[dogsdf_clean['retweeted_status_id'].notnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, favorite_count, retweet_count, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# ## Quality Issue #2: - Some of the entries are reply tweets from the WeRateDogs account on other Twitter accounts' tweets. We don't want to include these reply tweets in our analysis because they skew the data due to receiving far less exposure than the regular tweets that come directly from WeRateDogs themselves. The breed prediction model also doesn't work on these since the picture is not a direct part of the reply tweet.

# %% [markdown]
# Define:
#
# Similar to Quality Issue #1, We will be identifying all of the entries which have non NaN values in the "in_reply_to_status_id" column and deleting them from our dataframe.

# %% [markdown]
# Code:

# %%
for entries in range(len(dogsdf_clean)):
    if(np.isnan(dogsdf_clean['in_reply_to_status_id'][entries])):
        continue
    else:
        dogsdf_clean.drop([entries],inplace=True)

dogsdf_clean.reset_index(drop = True, inplace=True)

# %% [markdown]
# Check:

# %%
dogsdf_clean[dogsdf_clean['in_reply_to_status_id'].notnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, favorite_count, retweet_count, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []
#
# [0 rows x 31 columns]

# %%
dogsdf_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2097 entries, 0 to 2096
# Data columns (total 31 columns):
# Unnamed: 0                    2097 non-null int64
# tweet_id                      2097 non-null int64
# in_reply_to_status_id         0 non-null float64
# in_reply_to_user_id           0 non-null float64
# timestamp                     2097 non-null object
# source                        2097 non-null object
# text                          2097 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 2094 non-null object
# rating_numerator              2097 non-null int64
# rating_denominator            2097 non-null int64
# name                          2097 non-null object
# doggo                         2097 non-null object
# floofer                       2097 non-null object
# pupper                        2097 non-null object
# puppo                         2097 non-null object
# favorite_count                2072 non-null float64
# retweet_count                 2072 non-null float64
# jpg_url                       1971 non-null object
# img_num                       1971 non-null float64
# p1                            1971 non-null object
# p1_conf                       1971 non-null float64
# p1_dog                        1971 non-null object
# p2                            1971 non-null object
# p2_conf                       1971 non-null float64
# p2_dog                        1971 non-null object
# p3                            1971 non-null object
# p3_conf                       1971 non-null float64
# p3_dog                        1971 non-null object
# dtypes: float64(10), int64(4), object(17)
# memory usage: 507.9+ KB

# %% [markdown]
# ## Quality Issue #3: - Some of the remaining entries after cleaning the first two quality issues are not actually dog ratings and are just tweets about unrelated matters like bands or hotdogs or the date.

# %% [markdown]
# Define:
#
# Identify which tweets do not have any data under the "expanded_urls" column. Because this column should contain links to the picture of a dog which is required in a standard WeRateDogs tweet, a "NaN" value in this column for a row indicates that the tweet is unrelated and not a regular WeRateDogs dog rating.

# %% [markdown]
# Code:

# %%
for entries in range(len(dogsdf_clean)):
    if(pd.isnull(dogsdf_clean['expanded_urls'][entries])):
        dogsdf_clean.drop([entries],inplace=True)
    else:
        continue

dogsdf_clean.reset_index(drop = True, inplace=True)

# %% [markdown]
# Check:

# %%
dogsdf_clean[dogsdf_clean['expanded_urls'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, favorite_count, retweet_count, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # Quality Issue #4: There are a few tweets that seem to have been deleted at some time between its original posting and this project's commencement (October 2020). This means that Tweepy was unable to gather tweet favorite/retweet data since the tweet no longer exists.

# %% [markdown]
# Describe:
#
# Identify which tweets that Tweepy was unable to pull Favorite/Retweet counts on and then delete these from our dataframe

# %% [markdown]
# Code:

# %%
for entries in range(len(dogsdf_clean)):
    if(pd.isnull(dogsdf_clean['favorite_count'][entries])):
        dogsdf_clean.drop([entries],inplace=True)
    else:
        continue
        
dogsdf_clean.reset_index(drop = True, inplace=True)

# %% [markdown]
# Check:

# %%
dogsdf_clean[dogsdf_clean['favorite_count'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, favorite_count, retweet_count, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # Quality Issue #5: - There are a few tweets in which the image prediction algorithm was unable to produce a result. This is due to a multitude of possible reasons, examples of which include:
#
# 1.) The picture has been deleted due to copyright issues
#
# 2.) The tweet contains a video instead of a picture
#
# 3.) The tweet has been privatized or hidden (indicated by "This Tweet is unavailable")
#
# 4.) The tweet has pictures of multiple dogs instead of a single one
#
# For whatever reason this may be the case - we would like to remove these entries from our dataframe.

# %% [markdown]
# Code:

# %%
for entries in range(len(dogsdf_clean)):
    if(pd.isnull(dogsdf_clean['p1'][entries])):
        dogsdf_clean.drop([entries],inplace=True)
    else:
        continue
        
dogsdf_clean.reset_index(drop = True, inplace=True)

# %% [markdown]
# Check:

# %%
dogsdf_clean[dogsdf_clean['p1'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, favorite_count, retweet_count, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # Quality Issue #6: - There are some scores which have a denominator that is not equal to 10. This should not be the case since WeRateDogs is rigorously consistent in using a x/10 rating system. (Many of these appear to be because there are multiple dogs in the photo - we want to make sure each entry that we perform our data analysis/visualization on are all standardized to be one dog per rating and a rating out of 10).

# %% [markdown]
# Describe:
#
# Identify the entries which have denominators that are not out of 10 and then delete them.

# %% [markdown]
# Code:

# %%
for entries in range(len(dogsdf_clean)):
    if dogsdf_clean['rating_denominator'][entries] != 10:
        dogsdf_clean.drop([entries],inplace=True)
    else:
        continue
        
dogsdf_clean.reset_index(drop = True, inplace=True)

# %% [markdown]
# Check:

# %%
dogsdf_clean[dogsdf_clean['rating_denominator'] != 10]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, favorite_count, retweet_count, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# # Quality Issue #7: - Timestamp values do not need to have the "+0000" at the end. It should be in the "datetime" data type, not a string/object.

# %% [markdown]
# Describe:
#
# Parse the column values to delete the "+0000" and then use the datetime.strptime function to convert the values into datetime data type format.

# %% [markdown]
# Code:

# %%
# Code to remove "+0000" from variables
for entries in range(len(dogsdf_clean)):
    dogsdf_clean['timestamp'][entries] = dogsdf_clean['timestamp'][entries][:-6]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Code to convert object types to datetime
for entries in range(len(dogsdf_clean)):
    date_time_str = dogsdf_clean['timestamp'][entries]
    date_time_obj = datetime.datetime.strptime(date_time_str, '%Y-%m-%d %H:%M:%S')
    dogsdf_clean['timestamp'][entries] = date_time_obj
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %% [markdown]
# Check:

# %%
# Check that the "+0000" has been removed
dogsdf_clean['timestamp']
# Out:
# 0       2017-08-01 16:23:56
# 1       2017-08-01 00:17:27
# 2       2017-07-31 00:18:03
# 3       2017-07-30 15:58:51
# 4       2017-07-29 16:00:24
# 5       2017-07-29 00:08:17
# 6       2017-07-28 16:27:12
# 7       2017-07-28 00:22:40
# 8       2017-07-27 16:25:51
# 9       2017-07-26 15:59:51
# 10      2017-07-26 00:31:25
# 11      2017-07-25 16:11:53
# 12      2017-07-25 01:55:32
# 13      2017-07-25 00:10:02
# 14      2017-07-24 17:02:04
# 15      2017-07-24 00:19:32
# 16      2017-07-23 00:22:39
# 17      2017-07-22 16:56:37
# 18      2017-07-22 00:23:06
# 19      2017-07-20 16:49:33
# 20      2017-07-19 16:06:48
# 21      2017-07-19 03:39:09
# 22      2017-07-19 00:47:34
# 23      2017-07-18 16:08:03
# 24      2017-07-18 00:07:08
# 25      2017-07-17 16:17:36
# 26      2017-07-16 23:58:41
# 27      2017-07-16 20:14:00
# 28      2017-07-15 23:25:31
# 29      2017-07-15 16:17:19
#                ...
# 1900    2015-11-18 18:17:59
# 1901    2015-11-18 16:12:51
# 1902    2015-11-18 15:07:24
# 1903    2015-11-18 14:18:59
# 1904    2015-11-18 04:35:11
# 1905    2015-11-18 04:27:09
# 1906    2015-11-18 03:54:28
# 1907    2015-11-18 03:18:55
# 1908    2015-11-18 02:25:23
# 1909    2015-11-18 01:12:41
# 1910    2015-11-18 00:55:42
# 1911    2015-11-18 00:36:17
# 1912    2015-11-17 22:06:57
# 1913    2015-11-17 19:35:19
# 1914    2015-11-17 18:56:35
# 1915    2015-11-17 16:09:56
# 1916    2015-11-17 15:51:26
# 1917    2015-11-17 03:16:00
# 1918    2015-11-17 02:46:43
# 1919    2015-11-17 02:06:42
# 1920    2015-11-17 02:00:15
# 1921    2015-11-17 01:40:41
# 1922    2015-11-17 01:30:57
# 1923    2015-11-17 01:02:40
# 1924    2015-11-17 00:53:15
# 1925    2015-11-17 00:24:19
# 1926    2015-11-17 00:06:54
# 1927    2015-11-16 23:23:41
# 1928    2015-11-16 21:54:18
# 1929    2015-11-16 21:10:36
# Name: timestamp, Length: 1930, dtype: object

# %%
# Check that the variables are in datetime class
for entries in range(len(dogsdf_clean)):
    if isinstance(dogsdf_clean['timestamp'][entries], datetime.date):
        continue
    else:
        print ("Failed")

# %% [markdown]
# # Quality Issue #8: Retweet and Favorite Count should be integer datatype, not a float.

# %%
dogsdf_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1930 entries, 0 to 1929
# Data columns (total 31 columns):
# Unnamed: 0                    1930 non-null int64
# tweet_id                      1930 non-null int64
# in_reply_to_status_id         0 non-null float64
# in_reply_to_user_id           0 non-null float64
# timestamp                     1930 non-null object
# source                        1930 non-null object
# text                          1930 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 1930 non-null object
# rating_numerator              1930 non-null int64
# rating_denominator            1930 non-null int64
# name                          1930 non-null object
# doggo                         1930 non-null object
# floofer                       1930 non-null object
# pupper                        1930 non-null object
# puppo                         1930 non-null object
# favorite_count                1930 non-null float64
# retweet_count                 1930 non-null float64
# jpg_url                       1930 non-null object
# img_num                       1930 non-null float64
# p1                            1930 non-null object
# p1_conf                       1930 non-null float64
# p1_dog                        1930 non-null object
# p2                            1930 non-null object
# p2_conf                       1930 non-null float64
# p2_dog                        1930 non-null object
# p3                            1930 non-null object
# p3_conf                       1930 non-null float64
# p3_dog                        1930 non-null object
# dtypes: float64(10), int64(4), object(17)
# memory usage: 467.5+ KB

# %% [markdown]
# Describe:
#
# Convert Retweet and Favorite Count columns into integer datatypes.

# %% [markdown]
# Code:

# %%
dogsdf_clean['favorite_count'] = dogsdf_clean['favorite_count'].astype('int')
dogsdf_clean['retweet_count'] = dogsdf_clean['retweet_count'].astype('int')

# %% [markdown]
# Check:

# %%
dogsdf_clean['favorite_count'].dtype
# Out:
# dtype('int64')

# %%
dogsdf_clean['retweet_count'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# # Quality Issue #9: There are a few entries which have incorrect names for the dogs. This is either because there isn't a provided name in the tweet (which usually results in the name saying "an" or "a"), or the name was faultily extracted during the data gathering process.

# %% [markdown]
# Describe:
#
# Although it would be a difficult and complicated process to check every single entry to verify that the extracted names are correct, we can accomplish a good amount of cleaning on the names that are obviously incorrect by filtering out the ones that are 2 letters or less because these are usually incorrect entries that say "an" or "a" (there are a few exceptions to this e.g. some of the dogs are named "Bo" and we will leave them alone).

# %% [markdown]
# Code:

# %%
dogsdf_clean[dogsdf_clean['name'].map(len) < 3]
# Out:
#       Unnamed: 0            tweet_id  in_reply_to_status_id  \
# 49    56          881536004380872706 NaN
# 292   393         825876512159186944 NaN
# 329   449         819004803107983360 NaN
# 406   553         804026241225523202 NaN
# 466   649         792913359805018113 NaN
# 485   679         789137962068021249 NaN
# 555   775         776201521193218049 NaN
# 576   801         772581559778025472 NaN
# 591   820         770414278348247044 NaN
# 616   852         765395769549590528 NaN
# 636   876         761004547850530816 NaN
# 718   978         749996283729883136 NaN
# 739   1002        747885874273214464 NaN
# 741   1004        747816857231626240 NaN
# 749   1017        746872823977771008 NaN
# 753   1025        746369468511756288 NaN
# 774   1049        743222593470234624 NaN
# 906   1193        717537687239008257 NaN
# 915   1207        715733265223708672 NaN
# 1026  1340        704859558691414016 NaN
# 1043  1361        703079050210877440 NaN
# 1044  1362        703041949650034688 NaN
# 1049  1368        702539513671897089 NaN
# 1061  1382        700864154249383937 NaN
# 1161  1499        692187005137076224 NaN
# 1318  1683        681694085539872773 NaN
# 1357  1724        680085611152338944 NaN
# 1369  1737        679530280114372609 NaN
# 1411  1785        677644091929329666 NaN
# 1470  1853        675706639471788032 NaN
# ...    ...                       ...  ..
# 1549  1941        673715861853720576 NaN
# 1563  1955        673636718965334016 NaN
# 1596  1988        672834301050937345 NaN
# 1602  1994        672604026190569472 NaN
# 1642  2034        671743150407421952 NaN
# 1161  NaN                         ...    2.0     Siberian_husky
# 1318  NaN                         ...    1.0     toy_poodle
# 1357  NaN                         ...    3.0     pillow
# 1369  NaN                         ...    1.0     dalmatian
# 1411  NaN                         ...    1.0     Chihuahua
# 1470  NaN                         ...    1.0     English_springer
# ...   ...                         ...    ...                  ...
# 1549  NaN                         ...    1.0     suit
# 1563  NaN                         ...    1.0     wombat
# 1596  NaN                         ...    1.0     Pembroke
# 1602  NaN                         ...    1.0     toy_poodle
# 1642  NaN                         ...    1.0     toy_poodle
# 1647  NaN                         ...    1.0     Shetland_sheepdog
# 1672  NaN                         ...    1.0     Yorkshire_terrier
# 1722  NaN                         ...    1.0     seat_belt
# 1731  NaN                         ...    1.0     platypus
# 1734  NaN                         ...    1.0     Shetland_sheepdog
# 1752  NaN                         ...    1.0     car_mirror
# 1758  NaN                         ...    1.0     weasel
# 1766  NaN                         ...    1.0     toy_poodle
# 1794  NaN                         ...    1.0     cocker_spaniel
# 1801  NaN                         ...    1.0     redbone
# 1807  NaN                         ...    1.0     komondor
# 1814  NaN                         ...    1.0     bustard
# 1820  NaN                         ...    1.0     basenji
# 1821  NaN                         ...    1.0     Staffordshire_bullterrier
# 1824  NaN                         ...    1.0     shopping_basket
# 1837  NaN                         ...    1.0     Chihuahua
# 1851  NaN                         ...    1.0     malamute
# 1857  NaN                         ...    1.0     West_Highland_white_terrier
# 1864  NaN                         ...    1.0     Yorkshire_terrier
# 1873  NaN                         ...    1.0     toy_poodle
# 1887  NaN                         ...    1.0     vizsla
# 1903  NaN                         ...    1.0     swab
# 1910  NaN                         ...    1.0     Italian_greyhound
# 1913  NaN                         ...    1.0     Labrador_retriever
# 1926  NaN                         ...    1.0     black-and-tan_coonhound
#
#        p1_conf p1_dog                           p2   p2_conf p2_dog  \
# 49    0.281463  True   Angora                       0.272066  False
# 292   0.995941  False  shopping_basket              0.004057  False
# 329   0.351308  True   toy_poodle                   0.271929  True
# 406   0.492709  False  envelope                     0.050566  False
# 466   0.226716  False  lighter                      0.081941  False
# 485   0.746135  True   Pekinese                     0.070383  True
# 555   0.502228  True   black-and-tan_coonhound      0.154594  True
# 576   0.574345  True   Border_collie                0.128352  True
# 591   0.580528  False  maillot                      0.081449  False
# 616   0.509491  True   Cardigan                     0.330401  True
# 636   0.735163  True   Sussex_spaniel               0.064897  True
# 718   0.515319  True   West_Highland_white_terrier  0.151040  True
# 739   0.408450  True   Samoyed                      0.141330  True
# 741   0.768923  True   Chihuahua                    0.029053  True
# 749   0.540201  True   beagle                       0.207835  True
# 753   0.622957  True   malinois                     0.338884  True
# 774   0.350629  True   soft-coated_wheaten_terrier  0.182782  True
# 906   0.779356  True   Labrador_retriever           0.052511  True
# 915   0.740229  True   miniature_poodle             0.081915  True
# 1026  0.284428  True   teddy                        0.156339  False
# 1043  0.778503  True   Shetland_sheepdog            0.093834  True
# 1044  0.581403  False  doormat                      0.152445  False
# 1049  0.714367  True   Shih-Tzu                     0.040574  True
# 1061  0.805857  True   Great_Pyrenees               0.187272  True
# 1161  Eskimo_dog                      2.926480e-02  True
# 1318  Maltese_dog                     6.063720e-03  True
# 1357  wallet                          4.932580e-02  False
# 1369  zebra                           6.481490e-03  False
# 1411  swing                           5.984040e-02  False
# 1470  cocker_spaniel                  2.013780e-03  True
# ...              ...                           ...   ...
# 1549  Windsor_tie                     1.327010e-01  False
# 1563  pug                             1.904430e-02  True
# 1596  nipple                          3.383450e-02  False
# 1602  toilet_tissue                   2.911580e-04  False
# 1642  swing                           1.041930e-01  False
# 1647  papillon                        6.157010e-03  True
# 1672  silky_terrier                   5.869010e-02  True
# 1722  beagle                          3.226440e-03  True
# 1731  bison                           3.896910e-03  False
# 1734  guinea_pig                      1.562490e-01  False
# 1752  wing                            8.014850e-02  False
# 1758  hamster                         1.163740e-01  False
# 1766  standard_poodle                 8.252970e-02  True
# 1794  soft-coated_wheaten_terrier     6.700630e-02  True
# 1801  miniature_pinscher              1.097520e-01  True
# 1807  ram                             2.160900e-07  False
# 1814  crane                           8.471350e-02  False
# 1820  whippet                         5.191340e-02  True
# 1821  American_Staffordshire_terrier  1.124950e-01  True
# 1824  bassinet                        8.417350e-02  False
# 1837  giant_panda                     5.983750e-02  False
# 1851  Eskimo_dog                      1.127740e-02  True
# 1857  ice_bear                        6.903820e-02  False
# 1864  Australian_terrier              5.341200e-02  True
# 1873  Lakeland_terrier                7.331650e-02  True
# 1887  Weimaraner                      1.123690e-01  True
# 1903  wig                             3.450970e-02  False
# 1910  vizsla                          8.598910e-02  True
# 1913  French_bulldog                  2.075630e-02  True
# 1926  flat-coated_retriever           1.738100e-01  True
#
# [64 rows x 31 columns]

# %%
# From visually inspecting this subset, we can see that one of the incorrect
# names here is "O" when in fact the dog's full name is actually "O'Malley"

dogsdf_clean['name'][550] = "O'Malley"
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# For the entries which have names that say "an" or "a" - Some of these are because there are no names provided at all in the tweet. We can't do much to fix these, so we'll focus instead on those entries which DO have a name, but our data extraction process falsely selected "an" or "a" from the tweet as the name. Most of these tend to start with "This is a... named...".

# %%
dogsdf_clean[dogsdf_clean['text'].str.contains("This is a" and "name",regex=False)]
# Out:
#       Unnamed: 0            tweet_id  in_reply_to_status_id  \
# 133   168         859607811541651456 NaN
# 276   373         828376505180889089 NaN
# 616   852         765395769549590528 NaN
# 714   974         750056684286914561 NaN
# 852   1136        728387165835677696 NaN
# 1313  1678        682047327939461121 NaN
# 1352  1719        680161097740095489 NaN
# 1358  1725        680070545539371008 NaN
# 1366  1734        679736210798047232 NaN
# 1379  1748        679062614270468097 NaN
# 1470  1853        675706639471788032 NaN
# 1563  1955        673636718965334016 NaN
# 1642  2034        671743150407421952 NaN
# 1672  2066        671147085991960577 NaN
# 1692  2086        670803562457407488 NaN
# 1722  2116        670427002554466305 NaN
# 1731  2125        670361874861563904 NaN
# 1734  2128        670303360680108032 NaN
# 1752  2146        669923323644657664 NaN
# 1766  2161        669564461267722241 NaN
# 1771  2166        669363888236994561 NaN
# 1794  2191        668955713004314625 NaN
# 1807  2204        668636665813057536 NaN
# 1820  2218        668507509523615744 NaN
# 1903 NaN                  NaN
# 1905 NaN                  NaN
# 1910 NaN                  NaN
# 1912 NaN                  NaN
# 1913 NaN                  NaN
# 1917 NaN                  NaN
#
#      retweeted_status_timestamp   ...   img_num  \
# 133   NaN                         ...    1.0
# 276   NaN                         ...    1.0
# 616   NaN                         ...    1.0
# 714   NaN                         ...    1.0
# 852   NaN                         ...    1.0
# 1313  NaN                         ...    1.0
# 1352  NaN                         ...    1.0
# 1358  NaN                         ...    1.0
# 1366  NaN                         ...    1.0
# 1379  NaN                         ...    2.0
# 1470  NaN                         ...    1.0
# 1563  NaN                         ...    1.0
# 1642  NaN                         ...    1.0
# 1672  NaN                         ...    1.0
# 1692  NaN                         ...    1.0
# 1722  NaN                         ...    1.0
# 1731  NaN                         ...    1.0
# 1734  NaN                         ...    1.0
# 1752  NaN                         ...    1.0
# 1766  NaN                         ...    1.0
# 1771  NaN                         ...    1.0
# 1794  NaN                         ...    1.0
# 1807  NaN                         ...    1.0
# 1820  NaN                         ...    1.0
# 1829  NaN                         ...    1.0
# 1837  NaN                         ...    1.0
# 1851  NaN                         ...    1.0
# 1857  NaN                         ...    1.0
# 1864  NaN                         ...    1.0
# 1867  NaN                         ...    1.0
# 1869  NaN                         ...    1.0
# 1873  NaN                         ...    1.0
# 1887  NaN                         ...    1.0
# 1903  NaN                         ...    1.0
# 1905  NaN                         ...    1.0
# 1910  NaN                         ...    1.0
# 1912  NaN                         ...    1.0
# 1913  NaN                         ...    1.0
# 1917  NaN                         ...    1.0
#
#                                   p1   p1_conf p1_dog  \
# 133   golden_retriever                0.895529  True
# 276   American_Staffordshire_terrier  0.523086  True
# 616   Pembroke                        0.509491  True
# 714   Saluki                          0.484428  True
# 852   collie                          0.266414  True
# 1313  teddy                           0.364095  False
# 1352  bluetick                        0.268681  True
# 1358  earthstar                       0.127701  False
# 1366  French_bulldog                  0.319139  True
# 1379  cash_machine                    0.802333  False
# 1470  English_springer                0.990300  True
# 1563  wombat                          0.880257  False
# 1642  toy_poodle                      0.419427  True
# 1672  Yorkshire_terrier               0.467202  True
# 1692  basenji                         0.344101  True
# 1722  seat_belt                       0.952258  False
# 1731  platypus                        0.974075  False
# 1734  Shetland_sheepdog               0.380278  True
# 1752  car_mirror                      0.343063  False
# 1766  toy_poodle                      0.623685  True
# 1771  golden_retriever                0.539004  True
# 1794  cocker_spaniel                  0.367492  True
# 1807  komondor                        0.999956  True
# 1820  basenji                         0.055379  True
# 1829  Pembroke                        0.484830  True
# 1837  Chihuahua                       0.664834  True
# 1851  malamute                        0.967275  True
# 1857  West_Highland_white_terrier     0.360465  True
# 1864  Yorkshire_terrier               0.618957  True
# 1867  hare                            0.447893  False
# 1869  beagle                          0.636169  True
# 1873  toy_poodle                      0.304175  True
# 1887  vizsla                          0.259249  True
# 1903  swab                            0.589446  False
# 1905  Airedale                        0.448459  True
# 1910  Italian_greyhound               0.618316  True
# 1912  miniature_poodle                0.546933  True
# 1913  Labrador_retriever              0.887707  True
# 1917  dalmatian                       0.278954  True
#
# 1873  7.331650e-02  True
# 1887  1.123690e-01  True
# 1903  3.450970e-02  False
# 1905  1.101830e-01  False
# 1910  8.598910e-02  True
# 1912  9.595890e-02  True
# 1913  2.075630e-02  True
# 1917  1.711060e-01  True
#
# [39 rows x 31 columns]

# %%
dogsdf_clean['name'][132] = "Zoey"
dogsdf_clean['name'][611]='Zoey'
dogsdf_clean['name'][1307]='Thea'
dogsdf_clean['name'][1359]='Sabertooth'
dogsdf_clean['name'][1463] = "Wylie"
dogsdf_clean['name'][1556]="Kip"
dogsdf_clean['name'][1635]='Jacob'
dogsdf_clean['name'][1665]='Rufus'
dogsdf_clean['name'][1715]='Spork'
dogsdf_clean['name'][1724]='Cherokee'
dogsdf_clean['name'][1727]='Hemry'
dogsdf_clean['name'][1745]='Alphred'
dogsdf_clean['name'][1759]='Alfredo'
dogsdf_clean['name'][1764]='Zeus'
dogsdf_clean['name'][1787]='Leroi'
dogsdf_clean['name'][1800]='Berta'
dogsdf_clean['name'][1813]='Chuk'
dogsdf_clean['name'][1822]='Guss'
dogsdf_clean['name'][1830]='Alfonso'
dogsdf_clean['name'][1844]='Cheryl'
dogsdf_clean['name'][1850]='Jessiga'
dogsdf_clean['name'][1857]='Klint'
dogsdf_clean['name'][1860]='Big Jumpy Rat'
dogsdf_clean['name'][1862]='Tickles'
dogsdf_clean['name'][1866]='Kohl'
dogsdf_clean['name'][1880]='Daryl'
dogsdf_clean['name'][1896]='Pepe'
dogsdf_clean['name'][1903]='Octaviath'
dogsdf_clean['name'][1905]='Lugan'
dogsdf_clean['name'][1906]='Johm'
dogsdf_clean['name'][1910]='Kreggory'

dogsdf_clean.drop([1898],inplace=True) #This entry is actually two dogs, not one.
dogsdf_clean.reset_index(drop = True, inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dogsdf_clean['name'].replace(['a','an','the'],'None',inplace=True)

# %% [markdown]
# Check:

# %%
dogsdf_clean[(dogsdf_clean['name'] == 'a')|(dogsdf_clean['name'] == 'an')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, favorite_count, retweet_count, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# ## Tidiness Issue #1: There are a lot of extra columns, some of which don't provide any data or variables (e.g. Retweet ID and Reply To ID) particularly after deleting the retweeted and reply tweet entries (part of our Quality Issues cleaning process).
#
# This is also a good opportunity to remove any columns that we know we will not be using during our analysis/visualization.

# %% [markdown]
# Describe:
#
# Remove the columns which don't contain any variables as well as the "extra" columns

# %% [markdown]
# Code:

# %%
dogsdf_clean.drop(columns = ['in_reply_to_status_id','in_reply_to_user_id','retweeted_status_id',
                            'retweeted_status_user_id','retweeted_status_timestamp','expanded_urls',
                            'jpg_url','img_num','source'],inplace=True)

# %% [markdown]
# Check:

# %%
dogsdf_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1929 entries, 0 to 1928
# Data columns (total 22 columns):
# Unnamed: 0            1929 non-null int64
# tweet_id              1929 non-null int64
# timestamp             1929 non-null object
# text                  1929 non-null object
# rating_numerator      1929 non-null int64
# rating_denominator    1929 non-null int64
# name                  1929 non-null object
# doggo                 1929 non-null object
# floofer               1929 non-null object
# pupper                1929 non-null object
# puppo                 1929 non-null object
# favorite_count        1929 non-null int64
# retweet_count         1929 non-null int64
# p1                    1929 non-null object
# p1_conf               1929 non-null float64
# p1_dog                1929 non-null object
# p2                    1929 non-null object
# p2_conf               1929 non-null float64
# p2_dog                1929 non-null object
# p3                    1929 non-null object
# p3_conf               1929 non-null float64
# p3_dog                1929 non-null object
# dtypes: float64(3), int64(6), object(13)
# memory usage: 331.6+ KB

# %% [markdown]
# ## Tidiness Issue #2: The score should be one column instead of two (i.e. "Score" instead of "Rating Numerator" and "Rating Denominator"). The stage of the dog's life should be one column instead of four.

# %% [markdown]
# Define:
#
# Delete the rating_denominator column and rename the rating_numerator column into "score"

# %% [markdown]
# Code:

# %%
dogsdf_clean.drop(columns=['rating_denominator'],inplace=True)
dogsdf_clean.rename(columns={'rating_numerator':'score'},inplace=True)

# %% [markdown]
# Check:

# %%
dogsdf_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1929 entries, 0 to 1928
# Data columns (total 21 columns):
# Unnamed: 0        1929 non-null int64
# tweet_id          1929 non-null int64
# timestamp         1929 non-null object
# text              1929 non-null object
# score             1929 non-null int64
# name              1929 non-null object
# doggo             1929 non-null object
# floofer           1929 non-null object
# pupper            1929 non-null object
# puppo             1929 non-null object
# favorite_count    1929 non-null int64
# retweet_count     1929 non-null int64
# p1                1929 non-null object
# p1_conf           1929 non-null float64
# p1_dog            1929 non-null object
# p2                1929 non-null object
# p2_conf           1929 non-null float64
# p2_dog            1929 non-null object
# p3                1929 non-null object
# p3_conf           1929 non-null float64
# p3_dog            1929 non-null object
# dtypes: float64(3), int64(5), object(13)
# memory usage: 316.6+ KB

# %% [markdown]
# Define:
#
# Before we can consolidate the dog life stages into one column, we actually need to address the issue of how many of these entries don't actually have a classification into any of the four defined categories. We will mark each of these dogs with the tag "Other" so that they do not get looked over/deleted during the rest of our cleaning process.

# %% [markdown]
# Code:

# %%
dogsdf_clean['other'] = ''
for entries in range(len(dogsdf_clean)):
    if dogsdf_clean['doggo'][entries] == 'doggo':
        dogsdf_clean['other'][entries] = 'None'
    elif dogsdf_clean['floofer'][entries] == 'floofer':
        dogsdf_clean['other'][entries] = 'None'
    elif dogsdf_clean['pupper'][entries] == 'pupper':
        dogsdf_clean['other'][entries] = 'None'
    elif dogsdf_clean['puppo'][entries] == 'puppo':
        dogsdf_clean['other'][entries] = 'None'
    else:
        dogsdf_clean['other'][entries] = 'other'
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# Now we will use Panda's Melt function in order to consolidate the dog life stages into one column representing one variable. Concerning the rating columns, we can simply delete the "rating denominator" column since we've already made sure that every entry's score in our dataframe is standardized to be out of 10.

# %%
dogsdfb = dogsdf_clean

# %% [markdown]
# Code:

# %%
dogsdf_clean = pd.melt(dogsdf_clean, id_vars = ['tweet_id','timestamp',
                                               'text','name','favorite_count',
                                               'retweet_count','score','p1','p1_conf',
                                               'p1_dog','p2','p2_conf','p2_dog',
                                               'p3','p3_conf','p3_dog'],
                       value_vars = ['doggo','floofer','pupper','puppo','other'],
                       var_name = ['stage']
                      )

# %%
# This code deletes our duplicate entries and the extra "value" column
for entries in range(len(dogsdf_clean)):
# 26    None        22945           6651           11
# 27    None        10961           2238           11
# 28    Sunny       5564            938            14
# 29    Bo          0               8403           14
# ...   ..         ..                ...           ..
# 1899  None        399             288            12
# 1900  Klevin      98              31             9
# 1901  Carll       155             73             10
# 1902  Octaviath   170             78             11
# 1903  None        705             503            3
# 1904  Lugan       192             64             10
# 1905  Johm        269             128            12
# 1906  Jeph        179             81             9
# 1907  Jockson     451             312            8
# 1908  None        132             57             2
# 1909  Kreggory    157             70             10
# 1910  Josep       94              32             5
# 1911  Lugan       13322           5830           10
# 1912  None        69              11             8
# 1913  Christoper  140             57             8
# 1914  None        153             66             4
# 1915  Jimothy     99              41             9
# 1916  Kreggory    287             141            10
# 1917  Scout       134             52             9
# 1918  None        438             192            7
# 1919  None        103             52             10
# 1920  None        262             120            6
# 1921  None        404             216            7
# 1922  None        1101            753            12
# 1923  Walter      122             51             10
# 1924  quite       96              40             2
# 1925  None        265             125            7
# 1926  None        109             39             9
# 1927  None        119             41             11
# 1928  None        2356            454            6
#
#                                p1   p1_conf p1_dog  \
# 0     Pembroke                     0.511319  True
# 1     German_shepherd              0.707046  True
# 2     Labrador_retriever           0.476913  True
# 3     komondor                     0.974781  True
# 4     Chihuahua                    0.955156  True
# 5     golden_retriever             0.578120  True
# 6     flat-coated_retriever        0.321676  True
# 7     English_springer             0.354733  True
# 8     golden_retriever             0.650003  True
# 9     Dandie_Dinmont               0.394404  True
# 10    mortarboard                  0.936882  False
# 11    toilet_tissue                0.262936  False
# 12    boxer                        0.539036  True
# 13    Pembroke                     0.134081  True
# 14    whippet                      0.601712  True
# 15    Pomeranian                   0.153862  True
# 16    Old_English_sheepdog         0.999715  True
# 17    Labrador_retriever           0.315163  True
# 18    Staffordshire_bullterrier    0.757547  True
# 19    Bedlington_terrier           0.392535  True
# 20    golden_retriever             0.617389  True
# 21    Great_Pyrenees               0.858764  True
# 22    German_shepherd              0.741860  True
# 23    Labrador_retriever           0.782058  True
# 24    golden_retriever             0.980071  True
# 25    Irish_setter                 0.505496  True
# 26    Pomeranian                   0.856590  True
# 27    bathtub                      0.100896  False
# 28    prison                       0.907083  False
# 29    standard_poodle              0.351308  True
# ...               ...                   ...   ...
# 1899  golden_retriever             0.765266  True
# 1900  hyena                        0.987230  False
# 1901  hay                          0.507637  False
# 1902  swab                         0.589446  False
# 1903  triceratops                  0.442113  False
# 1904  Airedale                     0.448459  True
# 1905  Maltese_dog                  0.359383  True
# 1906  miniature_schnauzer          0.496953  True
# 1907  English_setter               0.328792  True
# 1908  snail                        0.999888  False
# 1909  Italian_greyhound            0.618316  True
# 1910  seat_belt                    0.375057  False
# 1911  miniature_poodle             0.546933  True
# 1912  Labrador_retriever           0.887707  True
# 1913  German_shepherd              0.975401  True
# 1914  Border_collie                0.447803  True
# 1915  Ibizan_hound                 0.044333  True
# 1916  dalmatian                    0.278954  True
# 1917  curly-coated_retriever       0.322084  True
# 1918  Chihuahua                    0.671853  True
# 1919  Chesapeake_Bay_retriever     0.184130  True
# 1920  llama                        0.505184  False
# 1921  Pembroke                     0.371361  True
# 1922  Blenheim_spaniel             0.906777  True
# 1923  toy_terrier                  0.149680  True
# 1924  coho                         0.404640  False
# 1925  black-and-tan_coonhound      0.529139  True
# 1926  Chihuahua                    0.978108  True
# 1927  soft-coated_wheaten_terrier  0.326467  True
# 1928  guinea_pig                   0.996496  False
#
#                                   p2   p2_conf p2_dog  \
# 0     Cardigan                        0.451038  True
# 1     malinois                        0.199396  True
# 2     Chesapeake_Bay_retriever        0.174145  True
# 3     briard                          0.020041  True
# 4     toy_terrier                     0.008054  True
# 5     Labrador_retriever              0.286059  True
# 6     Labrador_retriever              0.115138  True
# 7     collie                          0.177538  True
# 8     Leonberg                        0.065199  True
# 9     Maltese_dog                     0.186537  True
# 10    academic_gown                   0.020815  False
# 11    golden_retriever                0.226564  True
# 12    French_bulldog                  0.317617  True
# 13    ice_bear                        0.051928  False
# 14    Ibizan_hound                    0.152662  True
# 15    marmot                          0.091234  False
# 16    Tibetan_terrier                 0.000046  True
# 17    golden_retriever                0.153210  True
# 18    American_Staffordshire_terrier  0.149950  True
# 19    Labrador_retriever              0.089022  True
# 20    Labrador_retriever              0.337053  True
# 21    golden_retriever                0.023526  True
# 22    Tibetan_mastiff                 0.122812  True
# 23    golden_retriever                0.156581  True
# 24    Labrador_retriever              0.008758  True
# 25    vizsla                          0.168747  True
# 26    papillon                        0.038537  True
# 27    shower_curtain                  0.091866  False
# 28    palace                          0.020089  False
# 29    toy_poodle                      0.271929  True
# ...          ...                           ...   ...
# 1899  Labrador_retriever              0.206694  True
# 1900  African_hunting_dog             0.012601  False
# 1901  Rottweiler                      0.062490  True
# 1902  chain_saw                       0.190142  False
# 1903  armadillo                       0.114071  False
# 1904  toy_poodle                      0.124030  True
# 1905  teddy                           0.148759  False
# 1906  standard_schnauzer              0.285276  True
# 1907  Brittany_spaniel                0.283545  True
# 1908  slug                            0.000055  False
# 1909  Weimaraner                      0.151363  True
# 1910  miniature_pinscher              0.167175  True
# 1911  cocker_spaniel                  0.165255  True
# 1912  Chihuahua                       0.029307  True
# 1913  beagle                          0.008687  True
# 1914  English_springer                0.170497  True
# 1915  Pembroke                        0.043209  True
# 1916  Labrador_retriever              0.237612  True
# 1917  giant_schnauzer                 0.287955  True
# 1918  beagle                          0.124680  True
# 1919  chain_saw                       0.056775  False
# 1920  Irish_terrier                   0.104109  True
# 1921  chow                            0.249394  True
# 1922  cocker_spaniel                  0.090346  True
# 1923  papillon                        0.148258  True
# 1924  barracouta                      0.271485  False
# 1925  bloodhound                      0.244220  True
# 1926  toy_terrier                     0.009397  True
# 1927  Afghan_hound                    0.259551  True
# 1928  skunk                           0.002402  False
#
#                                p3   p3_conf p3_dog  stage
# 0     Chihuahua                    0.029248  True   doggo
# 1     Norwegian_elkhound           0.049148  True   doggo
# 2     German_short-haired_pointer  0.092861  True   doggo
# 3     swab                         0.003228  False  doggo
# 4     muzzle                       0.006296  False  doggo
# 5     bloodhound                   0.026917  True   doggo
# 6     groenendael                  0.096100  True   doggo
# 7     Border_collie                0.131706  True   doggo
# 8     Norfolk_terrier              0.052955  True   doggo
# 9     West_Highland_white_terrier  0.181985  True   doggo
# 10    schipperke                   0.011564  True   doggo
# 11    bathtub                      0.078879  False  doggo
# 12    bull_mastiff                 0.093928  True   doggo
# 13    pug                          0.044311  True   doggo
# 14    Italian_greyhound            0.135055  True   doggo
# 15    grey_fox                     0.090644  False  doggo
# 16    guinea_pig                   0.000041  False  doggo
# 17    Pekinese                     0.132791  True   doggo
# 18    Chesapeake_Bay_retriever     0.047523  True   doggo
# 19    clumber                      0.081800  True   doggo
# 20    tennis_ball                  0.008554  False  doggo
# 21    Pekinese                     0.017104  True   doggo
# 22    kelpie                       0.100460  True   doggo
# 23    soft-coated_wheaten_terrier  0.007275  True   doggo
# 24    Saluki                       0.001806  True   doggo
# 25    Chesapeake_Bay_retriever     0.111311  True   doggo
# 26    Yorkshire_terrier            0.033146  True   doggo
# 27    tub                          0.049176  False  doggo
# 28    umbrella                     0.007850  False  doggo
# 29    Tibetan_terrier              0.094759  True   doggo
# ...               ...                   ...   ...     ...
# 1899  seat_belt                    0.010667  False  other
# 1900  coyote                       0.000057  False  other
# 1901  water_buffalo                0.048425  False  other
# 1902  wig                          0.034510  False  other
# 1903  common_iguana                0.043255  False  other
# 1904  teddy                        0.110183  False  other
# 1905  West_Highland_white_terrier  0.106007  True   other
# 1906  giant_schnauzer              0.073764  True   other
# 1907  Ibizan_hound                 0.057461  True   other
# 1908  acorn                        0.000026  False  other
# 1909  vizsla                       0.085989  True   other
# 1910  Chihuahua                    0.086951  True   other
# 1911  toy_poodle                   0.095959  True   other
# 1912  French_bulldog               0.020756  True   other
# 1913  bloodhound                   0.005394  True   other
# 1914  collie                       0.139206  True   other
# 1915  West_Highland_white_terrier  0.038906  True   other
# 1916  Great_Pyrenees               0.171106  True   other
# 1917  Labrador_retriever           0.166331  True   other
# 1918  Saluki                       0.044094  True   other
# 1919  power_drill                  0.036763  False  other
# 1920  dingo                        0.062071  False  other
# 1921  Pomeranian                   0.241878  True   other
# 1922  Shih-Tzu                     0.001117  True   other
# 1923  Chihuahua                    0.142860  True   other
# 1924  gar                          0.189945  False  other
# 1925  flat-coated_retriever        0.173810  True   other
# 1926  papillon                     0.004577  True   other
# 1927  briard                       0.206803  True   other
# 1928  hamster                      0.000461  False  other
#
# [1929 rows x 17 columns]

# %% [markdown]
# # Saving our cleaned data into a new CSV file

# %%
dogsdf_clean.to_csv('twitter_archive_master.csv',index=False)

# %% [markdown]
# # Insights and Visualization

# %%
df = pd.read_csv('twitter_archive_master.csv')

# %%
df['score'].describe()
# Out:
# count    1929.000000
# mean     11.750130
# std      41.341656
# min      0.000000
# 25%      10.000000
# 50%      11.000000
# 75%      12.000000
# max      1776.000000
# Name: score, dtype: float64

# %%
df.sort_values(by=['score'],ascending=False).head(5)
# Out:
#                 tweet_id            timestamp  \
# 896   749981277374128128  2016-07-04 15:00:45
# 1680  670842764863651840  2015-11-29 05:52:33
# 714   786709082849828864  2016-10-13 23:23:56
# 110   778027034220126208  2016-09-20 00:24:34
# 1401  680494726643068929  2015-12-25 21:06:00
#
#                                                                                                                                                                    text  \
# 896   This is Atticus. He's quite simply America af. 1776/10 https://t.co/GRXwMxLBkh
# 1680  After so many requests... here you go.\n\nGood dogg. 420/10 https://t.co/yfAAo1gdeY
# 714   This is Logan, the Chow who lived. He solemnly swears he's up to lots of good. H*ckin magical af 9.75/10 https://t.co/yBO5wuqaPS
# 110   This is Sophie. She's a Jubilant Bush Pupper. Super h*ckin rare. Appears at random just to smile at the locals. 11.27/10 would smile back https://t.co/QFaUiIHxHq
# 1401  Here we have uncovered an entire battalion of holiday puppers. Average of 11.26/10 https://t.co/eNm2S6p9BD
#
#          name  favorite_count  retweet_count  score          p1   p1_conf  \
# 896   Atticus  2765            731            1776   bow_tie     0.533941
# 1680  None     1116            446            420    microphone  0.096063
# 714   Logan    20001           7995           75     Pomeranian  0.467321
# 110   Sophie   7333            2928           27     clumber     0.946718
# 1401  None     4636            2015           26     kuvasz      0.438627
#
#       p1_dog              p2   p2_conf  p2_dog              p3   p3_conf  \
# 896   False   sunglasses      0.080822  False   sunglass        0.050776
# 1680  False   accordion       0.094075  False   drumstick       0.061113
# 714   True    Persian_cat     0.122978  False   chow            0.102654
# 110   True    cocker_spaniel  0.015950  True    Lhasa           0.006519
# 1401  True    Samoyed         0.111622  True    Great_Pyrenees  0.064061
#
#       p3_dog   stage
# 896   False   other
# 1680  False   other
# 714   True    other
# 110   True    pupper
# 1401  True    other

# %%
plt.hist(df['score'], bins=30, range=(0,14));
plt.xlabel('Score')
plt.ylabel('Number of Tweets')
plt.title('WeRateDogs Tweet Scores Between November 2015 and July 2017');

# %% [markdown]
# The most commonly awarded score (the "mode") of the dataset is a 12/10, which is above the mean of 11.75. This dataset is skewed left, which indicates that it is more common for outliers that deviate from the typical 10 - 14 range to be scored below the average than above it. In fact, whereas there are a good number of dogs who scored below a 10/10, there are only 5 dogs in the entire archive who were scored higher than a 14 (all of which are therefore not captured in the histogram visualization above).

# %%
plt.bar(x=['Cooper','Charlie', 'Oliver', 'Lucy', 'Tucker'], height=[10,11,10,10,9]);
plt.xlabel('Dog Names')
plt.ylabel('Number of Dogs')
plt.title('Top 5 Common Dog Names');

# %% [markdown]
# The most common dog name in this archive is Charlie, closely followed by a 3 way tie for second between Cooper, Oliver, and Lucy.

# %%
df.sort_values(by=['favorite_count'],ascending=False).head(5)
# Out:
#                tweet_id            timestamp  \
# 920  747103485104099331  2016-06-26 16:25:26
# 616  810896069567610880  2016-12-19 17:14:23
# 285  867421006826221569  2017-05-24 16:44:18
# 945  742385895052087300  2016-06-13 15:59:24
# 352  879492040517615616  2017-06-27 00:10:17
#
#                                                                                                                                                               text  \
# 920  Guys... I said DOGS with "shark qualities" or "costumes." Not actual sharks. This did me a real frighten ...11/10 https://t.co/DX1JUHJVN7
# 616  This is Hunter. He just found out he needs braces. Requesting an orthodogtist stat. 11/10 you're fine Hunter, everything's fine https://t.co/zW1o0W4AYV
# 285  This is Shikha. She just watched you drop a skittle on the ground and still eat it. Could not be less impressed. 12/10 superior puppo https://t.co/XZlZKd73go
# 945  This is Phil. That's his comfort stick. He holds onto it whenever he's sad. 11/10 don't be sad Phil https://t.co/ULdPY6CLpq
# 352  This is Bailey. He thinks you should measure ear length for signs of growth instead. 12/10 https://t.co/IxM9IMKQq8
#
#        name  favorite_count  retweet_count  score  \
# 920  None    152944          75701          11
# 616  Hunter  118100          55178          11
# 285  Shikha  114238          32163          12
# 945  Phil    113075          56328          11
# 352  Bailey  97422           39704          12
#
#                               p1   p1_conf  p1_dog                  p2  \
# 920  Labrador_retriever           0.991954  True    golden_retriever
# 616  flat-coated_retriever        0.820804  True    Labrador_retriever
# 285  Eskimo_dog                   0.616457  True    Siberian_husky
# 945  Cardigan                     0.566911  True    Border_collie
# 352  German_short-haired_pointer  0.479896  True    vizsla
#
#       p2_conf  p2_dog                      p3   p3_conf  p3_dog  stage
# 920  0.002228  True    doormat                 0.001404  False   other
# 616  0.082318  True    curly-coated_retriever  0.067461  True    other
# 285  0.381330  True    malamute                0.001670  True    puppo
# 945  0.117566  True    Appenzeller             0.047664  True    other
# 352  0.124353  True    bath_towel              0.073320  False   other

# %%
df.sort_values(by=['retweet_count'],ascending=False).head(5)
# Out:
#                tweet_id            timestamp  \
# 920  747103485104099331  2016-06-26 16:25:26
# 945  742385895052087300  2016-06-13 15:59:24
# 616  810896069567610880  2016-12-19 17:14:23
# 352  879492040517615616  2017-06-27 00:10:17
# 565  821044531881721856  2017-01-16 17:20:45
#
#                                                                                                                                                         text  \
# 920  Guys... I said DOGS with "shark qualities" or "costumes." Not actual sharks. This did me a real frighten ...11/10 https://t.co/DX1JUHJVN7
# 945  This is Phil. That's his comfort stick. He holds onto it whenever he's sad. 11/10 don't be sad Phil https://t.co/ULdPY6CLpq
# 616  This is Hunter. He just found out he needs braces. Requesting an orthodogtist stat. 11/10 you're fine Hunter, everything's fine https://t.co/zW1o0W4AYV
# 352  This is Bailey. He thinks you should measure ear length for signs of growth instead. 12/10 https://t.co/IxM9IMKQq8
# 565  This is Flash. He went way too hard celebrating Martin Luther King Day last night. 12/10 now he's having a dream in his honor https://t.co/bryVdNaRcu
#
#        name  favorite_count  retweet_count  score  \
# 920  None    152944          75701          11
# 945  Phil    113075          56328          11
# 616  Hunter  118100          55178          11
# 352  Bailey  97422           39704          12
# 565  Flash   0               36568          12
#
#                               p1   p1_conf  p1_dog                  p2  \
# 920  Labrador_retriever           0.991954  True    golden_retriever
# 945  Cardigan                     0.566911  True    Border_collie
# 616  flat-coated_retriever        0.820804  True    Labrador_retriever
# 352  German_short-haired_pointer  0.479896  True    vizsla
# 565  Old_English_sheepdog         0.148020  True    Airedale
#
#       p2_conf  p2_dog                      p3   p3_conf  p3_dog  stage
# 920  0.002228  True    doormat                 0.001404  False   other
# 945  0.117566  True    Appenzeller             0.047664  True    other
# 616  0.082318  True    curly-coated_retriever  0.067461  True    other
# 352  0.124353  True    bath_towel              0.073320  False   other
# 565  0.133534  True    Tibetan_mastiff         0.120903  True    other

# %% [markdown]
# The dog with the highest amount of favorites AND retweets in the dataset is an unnamed labrador who dressed up as a shark. 4 dogs are in both of the Top 5 for the Most Favorited and also the Most Retweeted lists, suggesting that those dogs who tend to receive a lot of favorites on the twitter page also receive a lot of retweets.
